# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error

# %%
df = pd.read_csv("Coffe_sales.csv")
df
# Out:
#       hour_of_day cash_type  money    coffee_name Time_of_Day Weekday  \
# 0              10      card  38.70          Latte     Morning     Fri
# 1              12      card  38.70  Hot Chocolate   Afternoon     Fri
# 2              12      card  38.70  Hot Chocolate   Afternoon     Fri
# 3              13      card  28.90      Americano   Afternoon     Fri
# 4              13      card  38.70          Latte   Afternoon     Fri
# ...           ...       ...    ...            ...         ...     ...
# 3542           10      card  35.76     Cappuccino     Morning     Sun
# 3543           14      card  35.76          Cocoa   Afternoon     Sun
# 3544           14      card  35.76          Cocoa   Afternoon     Sun
# 3545           15      card  25.96      Americano   Afternoon     Sun
# 3546           18      card  35.76          Latte       Night     Sun
#
#      Month_name  Weekdaysort  Monthsort        Date             Time
# ...

# %%
df.drop("Time",axis=1,inplace=True)
df
# Out:
#       hour_of_day cash_type  money    coffee_name Time_of_Day Weekday  \
# 0              10      card  38.70          Latte     Morning     Fri
# 1              12      card  38.70  Hot Chocolate   Afternoon     Fri
# 2              12      card  38.70  Hot Chocolate   Afternoon     Fri
# 3              13      card  28.90      Americano   Afternoon     Fri
# 4              13      card  38.70          Latte   Afternoon     Fri
# ...           ...       ...    ...            ...         ...     ...
# 3542           10      card  35.76     Cappuccino     Morning     Sun
# 3543           14      card  35.76          Cocoa   Afternoon     Sun
# 3544           14      card  35.76          Cocoa   Afternoon     Sun
# 3545           15      card  25.96      Americano   Afternoon     Sun
# 3546           18      card  35.76          Latte       Night     Sun
#
#      Month_name  Weekdaysort  Monthsort        Date
# 0           Mar            5          3  2024-03-01
# ...

# %%
df.drop("Date",axis=1,inplace=True)
df
# Out:
#       hour_of_day cash_type  money    coffee_name Time_of_Day Weekday  \
# 0              10      card  38.70          Latte     Morning     Fri
# 1              12      card  38.70  Hot Chocolate   Afternoon     Fri
# 2              12      card  38.70  Hot Chocolate   Afternoon     Fri
# 3              13      card  28.90      Americano   Afternoon     Fri
# 4              13      card  38.70          Latte   Afternoon     Fri
# ...           ...       ...    ...            ...         ...     ...
# 3542           10      card  35.76     Cappuccino     Morning     Sun
# 3543           14      card  35.76          Cocoa   Afternoon     Sun
# 3544           14      card  35.76          Cocoa   Afternoon     Sun
# 3545           15      card  25.96      Americano   Afternoon     Sun
# 3546           18      card  35.76          Latte       Night     Sun
#
#      Month_name  Weekdaysort  Monthsort
# 0           Mar            5          3
# 1           Mar            5          3
# ...

# %%
df.drop("Time_of_Day",axis=1,inplace=True)
df
# Out:
#       hour_of_day cash_type  money    coffee_name Weekday Month_name  \
# 0              10      card  38.70          Latte     Fri        Mar
# 1              12      card  38.70  Hot Chocolate     Fri        Mar
# 2              12      card  38.70  Hot Chocolate     Fri        Mar
# 3              13      card  28.90      Americano     Fri        Mar
# 4              13      card  38.70          Latte     Fri        Mar
# ...           ...       ...    ...            ...     ...        ...
# 3542           10      card  35.76     Cappuccino     Sun        Mar
# 3543           14      card  35.76          Cocoa     Sun        Mar
# 3544           14      card  35.76          Cocoa     Sun        Mar
# 3545           15      card  25.96      Americano     Sun        Mar
# 3546           18      card  35.76          Latte     Sun        Mar
#
#       Weekdaysort  Monthsort
# 0               5          3
# 1               5          3
# 2               5          3
# ...

# %%
df.isna().sum()
# Out:
# hour_of_day    0
# cash_type      0
# money          0
# coffee_name    0
# Weekday        0
# Month_name     0
# Weekdaysort    0
# Monthsort      0
# dtype: int64

# %%
df['coffee_name'].nunique()
# Out:
# 8

# %%
#encoding--converting string into numerical 
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for column in ["cash_type","coffee_name","Weekday","Month_name"]:
    df[column]=le.fit_transform(df[column])
df
# Out:
#       hour_of_day  cash_type  money  coffee_name  Weekday  Month_name  \
# 0              10          0  38.70            7        0           7
# 1              12          0  38.70            6        0           7
# 2              12          0  38.70            6        0           7
# 3              13          0  28.90            0        0           7
# 4              13          0  38.70            7        0           7
# ...           ...        ...    ...          ...      ...         ...
# 3542           10          0  35.76            2        3           7
# 3543           14          0  35.76            3        3           7
# 3544           14          0  35.76            3        3           7
# 3545           15          0  25.96            0        3           7
# 3546           18          0  35.76            7        3           7
#
#       Weekdaysort  Monthsort
# 0               5          3
# 1               5          3
# 2               5          3
# ...

# %%
#separate the independent and dependent variables
x = df.drop(columns=['money'])  #Independent variables
y = df['money']

# %%
x.columns
# Out:
# Index(['hour_of_day', 'cash_type', 'coffee_name', 'Weekday', 'Month_name',
#        'Weekdaysort', 'Monthsort'],
#       dtype='object')

# %%
y
# Out:
# 0       38.70
# 1       38.70
# 2       38.70
# 3       28.90
# 4       38.70
#         ...
# 3542    35.76
# 3543    35.76
# 3544    35.76
# 3545    25.96
# 3546    35.76
# Name: money, Length: 3547, dtype: float64

# %%
ss=StandardScaler()
x_scaled= ss.fit_transform(x)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)   #spliting data--0.3=70%,30%
print(x_train,x_test,y_train,y_test)
# Out:
#       hour_of_day  cash_type  coffee_name  Weekday  Month_name  Weekdaysort  \
# 944            21          0            0        6           5            3
# 199            14          0            2        2           0            6
# 3351           15          0            0        1           7            1
# 2276           16          0            2        5           9            2
# 801            17          0            6        2           6            6
# ...           ...        ...          ...      ...         ...          ...
# 1130           11          0            4        2           1            6
# 1294           10          0            7        1           1            1
# 860            11          0            1        5           5            2
# 3507           19          0            2        4           7            4
# 3174            8          0            0        6           3            3
#
#       Monthsort
# 944           7
# 199           4
# ...

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (2482, 7)
# (1065, 7)
# (2482,)
# (1065,)

# %%
#model training
model=LinearRegression()
model.fit(x_train,y_train)
model
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test) 
y_pred
# Out:
# array([30.60177662, 34.45624217, 31.66620197, ..., 29.07699991,
#        30.29168129, 34.47183338])

# %%
#evaluate modle
mse=mean_squared_error(y_test,y_pred)
print(f"Mean Squared Error : {mse}")
# Out:
# Mean Squared Error : 17.867252126416535

# %%
mae = mean_absolute_error(y_test, y_pred)
print(f"Mean absolute Error : {mae}")
# Out:
# Mean absolute Error : 3.2808567852286785

# %%
r2=r2_score(y_test,y_pred) #0,100
#r2_score-evaluates how well the regression model fits the date
print(f"R-squared : {r2*100}")
# Out:
# R-squared : 23.43242279002148

# %%
#predicting new model
new_experience=np.array([[10,0,7,0,7,5,3]]) #predicting sales for 5 years of 
predicted_sale=model.predict(new_experience)
print(f"predicting sales for 5 years :$ {predicted_sale}")
# Out:
# predicting sales for 5 years :$ [34.74123533]
# C:\Users\Appi\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
#plot the confusion matrix
plt.figure(figsize=(5,5))
sns.heatmap(conf_matrix,annot=True,fmt='d',cmap='Blues',xticklabels=rf_model.classes_,yticklabels=rf_model.classes_)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
